# %%
# import the module build in a different folder
from scattering_structure.scattering_structure import ScatteringStructure
import numpy as np
import importlib.util
import os

# %% [markdown]
# ## Density 0.3/um^2

# %%
pois = ScatteringStructure(geometry={'type': 'circle', 'lx': 200, 'ly': 200,
                                     'circle_radius': 90},
                           arrangement={'type':'poisson_disc', 'optimization': True,
                                        'measure_of_merit':'density',
                                        'target_mom': 0.3,
                                        'optimization_outer_n': 4,
                                        'optimization_inner_n': 8},
                           scatterer_radius=1.343
                           )
pois.plot_device()
pois_density = pois.density()

# print for further use
print('Density = ', pois_density, '/um^2')
# Out:
# Density =  0.3085316928965717 /um^2

# %%
pois.save_device(filepath="devices_files/density_0,3.txt")
# Out:
# Distribution saved to devices_files/density_0,3.txt

# %% [markdown]
# ## 0.2/um^2

# %%
pois = ScatteringStructure(geometry={'type': 'circle', 'lx': 200, 'ly': 200,
                                     'circle_radius': 90},
                           arrangement={'type':'poisson_disc', 'optimization': True,
                                        'measure_of_merit':'density',
                                        'target_mom': 0.2,
                                        'optimization_outer_n': 4,
                                        'optimization_inner_n': 8},
                           scatterer_radius=1.343
                           )
pois.plot_device()
pois_density = pois.density()

# print for further use
print('Density = ', pois_density, '/um^2')
# Out:
# Density =  0.19817990742070882 /um^2

# %%
pois.save_device(filepath="devices_files/density_0,2.txt")
# Out:
# Distribution saved to devices_files/density_0,2.txt

# %% [markdown]
# ## 0.1/um^2

# %%
pois = ScatteringStructure(geometry={'type': 'circle', 'lx': 200, 'ly': 200,
                                     'circle_radius': 90},
                           arrangement={'type':'poisson_disc', 'optimization': True,
                                        'measure_of_merit':'density',
                                        'target_mom': 0.1,
                                        'optimization_outer_n': 4,
                                        'optimization_inner_n': 8},
                           scatterer_radius=1.343
                           )
pois.plot_device()
pois_density = pois.density()

# print for further use
print('Density = ', pois_density, '/um^2')
# Out:
# Density =  0.10114399849777418 /um^2

# %%
pois.save_device(filepath="devices_files/density_0,1.txt")
# Out:
# Distribution saved to devices_files/density_0,1.txt

# %% [markdown]
# ## 0.08/um^2

# %%
pois = ScatteringStructure(geometry={'type': 'circle', 'lx': 200, 'ly': 200,
                                     'circle_radius': 90},
                           arrangement={'type':'poisson_disc', 'optimization': True,
                                        'measure_of_merit':'density',
                                        'target_mom': 0.08,
                                        'optimization_outer_n': 4,
                                        'optimization_inner_n': 8},
                           scatterer_radius=1.343
                           )
pois.plot_device()
pois_density = pois.density()

# print for further use
print('Density = ', pois_density, '/um^2')
# Out:
# Density =  0.08017857583997226 /um^2

# %%
pois.save_device(filepath="devices_files/density_0,08.txt")
# Out:
# Distribution saved to devices_files/density_0,8.txt

# %% [markdown]
# ## 0.06/um^2

# %%
pois = ScatteringStructure(geometry={'type': 'circle', 'lx': 200, 'ly': 200,
                                     'circle_radius': 90},
                           arrangement={'type':'poisson_disc', 'optimization': True,
                                        'measure_of_merit':'density',
                                        'target_mom': 0.06,
                                        'optimization_outer_n': 4,
                                        'optimization_inner_n': 8},
                           scatterer_radius=1.343
                           )
pois.plot_device()
pois_density = pois.density()

# print for further use
print('Density = ', pois_density, '/um^2')
# Out:
# Density =  0.060204761010579866 /um^2

# %%
pois.save_device(filepath="devices_files/density_0,06.txt")
# Out:
# Distribution saved to devices_files/density_0,06.txt

# %% [markdown]
# ## 0.04/um^2

# %%
pois = ScatteringStructure(geometry={'type': 'circle', 'lx': 200, 'ly': 200,
                                     'circle_radius': 90},
                           arrangement={'type':'poisson_disc', 'optimization': True,
                                        'measure_of_merit':'density',
                                        'target_mom': 0.04,
                                        'optimization_outer_n': 4,
                                        'optimization_inner_n': 8},
                           scatterer_radius=1.343
                           )
pois.plot_device()
pois_density = pois.density()

# print for further use
print('Density = ', pois_density, '/um^2')
# Out:
# Density =  0.03994762965878476 /um^2

# %%
pois.save_device(filepath="devices_files/density_0,04.txt")
# Out:
# Distribution saved to devices_files/density_0,04.txt

# %% [markdown]
# ## 0.02/um^2

# %%
pois = ScatteringStructure(geometry={'type': 'circle', 'lx': 200, 'ly': 200,
                                     'circle_radius': 90},
                           arrangement={'type':'poisson_disc', 'optimization': True,
                                        'measure_of_merit':'density',
                                        'target_mom': 0.02,
                                        'optimization_outer_n': 4,
                                        'optimization_inner_n': 8},
                           scatterer_radius=1.343
                           )
pois.plot_device()
pois_density = pois.density()

# print for further use
print('Density = ', pois_density, '/um^2')
# Out:
# Density =  0.02280698005341967 /um^2

# %%
pois.save_device(filepath="devices_files/density_0,02.txt")
# Out:
# Distribution saved to devices_files/density_0,02.txt

# %% [markdown]
# ## 0.01/um^2

# %%
pois = ScatteringStructure(geometry={'type': 'circle', 'lx': 200, 'ly': 200,
                                     'circle_radius': 90},
                           arrangement={'type':'poisson_disc', 'optimization': True,
                                        'measure_of_merit':'density',
                                        'target_mom': 0.015,
                                        'optimization_outer_n': 4,
                                        'optimization_inner_n': 8},
                           scatterer_radius=1.343
                           )
pois.plot_device()
pois_density = pois.density()

# print for further use
print('Density = ', pois_density, '/um^2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 pois = ScatteringStructure(geometry={'type': 'circle', 'lx': 200, 'ly': 200,
#       2                                      'circle_radius': 90},
#       3                            arrangement={'type':'poisson_disc', 'optimization': True,
#       4                                         'measure_of_merit':'density',
#       5                                         'target_mom': 0.015,
#       6                                         'optimization_outer_n': 4,
#       7                                         'optimization_inner_n': 8},
#       8                            scatterer_radius=1.343
#       9                            )
#      10 pois.plot_device()
#      11 pois_density = pois.density()
#
# File ~\PycharmProjects\Scattering-Structures\scattering_structure\scattering_structure.py:23, in ScatteringStructure.__init__(self, geometry, arrangement, scatterer_radius, position)
#      21     self.points = self.create_random_pattern()
#      22 elif arrangement['type'] == 'poisson_disc':
# ---> 23     self.points = self.create_poisson_disc_sampling_pattern()
#      24 elif arrangement['type'] == 'load_from_file':
#      25     self.points = self.load(arrangement['filepath'])
#
# File ~\PycharmProjects\Scattering-Structures\scattering_structure\scattering_structure.py:158, in ScatteringStructure.create_poisson_disc_sampling_pattern(self)
#     154 middle = 5 * self.scatterer_radius
#     155 for i in range(self.arrangement['optimization_outer_n']):
#     156     # print(i)
#     157     # get the pattern closest to target mom in initial range
# --> 158     pattern, middle = self._poisson_pattern_optimisation(start=middle - 0.5 * rng,
#     159                                                          stop=middle + 0.5 * rng,
#     160                                                          n=self.arrangement['optimization_inner_n'])
#     161     # cut the range by half
#     162     rng *= 0.5
#
# File ~\PycharmProjects\Scattering-Structures\scattering_structure\scattering_structure.py:179, in ScatteringStructure._poisson_pattern_optimisation(self, start, stop, n)
#     176 # compute a pattern for each radius
#     177 for r in radii:
#     178     # print(r)
# --> 179     pattern = poisson_disc.Bridson_sampling(radius=r, dims=np.array([max_x, max_y]))
#     180     current_mom = self._measure_of_merit(pattern)
#     181     # check if measure of merit has improved
#
# File ~\PycharmProjects\Scattering-Structures\venv\Lib\site-packages\poisson_disc.py:84, in Bridson_sampling(dims, radius, k, hypersphere_sample)
#      81 squared_radius = radius*radius
#      83 # Positions of cells
# ---> 84 P = np.empty(np.append(gridsize, ndim), dtype=np.float32) #n-dim value for each grid cell
#      85 # Initialise empty cells with NaNs
#      86 P.fill(np.nan)
#
# ValueError: negative dimensions are not allowed

# %% [markdown]
# I dont get this error. I'll leave it to five sweep points for now
